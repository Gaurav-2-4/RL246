# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaurav-2-4/RL246/blob/main/correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x = np.random.randint(0,50,1000)

# %%
y = x + np.random.normal(0,10,1000)

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.80719132],
#        [0.80719132, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show()

# %%
y = x - np.random.normal(0,10,1000)
plt.scatter(x,y)
plt.show()

# %%
import pandas as pd
df = pd.DataFrame({'a':np.random.randint(0,50,1000)})
df['b'] = df['a'] + np.random.normal(0,10,1000)
df['c'] = 100 - df['a'] + np.random.normal(0,5,1000)
df['d'] = np.random.randint(0,50,1000)
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.816534 -0.944417  0.000883
# b  0.816534  1.000000 -0.762387 -0.009521
# c -0.944417 -0.762387  1.000000  0.002019
# d  0.000883 -0.009521  0.002019  1.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, sort_ascending=False, figscale=1):
#   from matplotlib import pyplot as plt
#   figsize = (8 * figscale, 4 * figscale)
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_44, *['a'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# ...

# %%
pd.plotting.scatter_matrix(df,figsize=(6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()
